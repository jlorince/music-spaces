# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd

features = np.load('/Users/jaredlorince/git/MusicForaging/GenreModeling/data/features/lda_artists/features_190.npy')

# %%
from scipy.stats import entropy
x=np.apply_along_axis(entropy,1,features)

# %%
sns.distplot(x)

# %%
artist_dict = {}
with open('/Users/jaredlorince/git/MusicForaging/GenreModeling/data/artist_ids') as f:
    for line in f:
        line = line.strip().split('\t')
        artist_dict[int(line[0])] = line[1]
        #artist_dict[line[1]] = int(line[0])
feature_dict = {}
with open('/Users/jaredlorince/git/MusicForaging/GenreModeling/data/artist_idx_feature_map') as f:
    for line in f:
        line = line.strip().split('\t')
        feature_dict[int(line[0])] = int(line[1])

# %%
fig, ax = plt.subplots(1,1)
td = pd.Series(np.load('../data/timediffs.npy'))
plt.plot(td/td.sum())
ax.set_xscale('log')
ax.set_yscale('log')

# %%
fig, ax = plt.subplots(1,1)
plt.plot(td.cumsum()/td.sum())
ax.set_xscale('log')
ax.set_yscale('log')
